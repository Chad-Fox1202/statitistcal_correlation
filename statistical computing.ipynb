# %%
import pandas as pd

df = pd.read_csv('tj.csv')

df2 = pd.read_csv('no_tj_differences.csv')

# %%
age=df['age before surgery ']
ageNoTJ=df2['player_age']

recov=df['recovery_time']

surgeon=df['surgeon']

andrews=df['Andrews x ']

neal=df['Neal']

kpercent=df['k_percentage diff']
kpercentNoTJ = df2['k_percentage diff']

bbpercent=df['bb_percentage diff']
bbpercentNoTJ=df2['bb_percentage diff']

exitvelo=df['avg_exit_velocity diff']
exitveloNpTJ=df2['avg_exit_velocity diff']

hardhit=df['hard_hit_percentage diff']
hardhitNoTJ=df2['hard_hit_percentage diff']

fastvelo=df['ff_velo diff']
fastveloNoTJ=df2['ff_velo diff']

fastrpm=df['ff_rpm diff']
fastrpmNoTJ=df2['ff_rpm diff']

era=df['era diff']
eraNoTJ=df2['era diff ']

whip=df['whip diff ']
whipNoTJ=df2['whip diff']

# %%
import statsmodels.api as sm

# %%
#regression models with surgeon
X=pd.DataFrame({'andrews':andrews,'neal':neal})
y=pd.DataFrame({'recov':recov})
model1=sm.OLS(y,X)
results=model1.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  recov   R-squared (uncentered):                   0.483
# Model:                            OLS   Adj. R-squared (uncentered):              0.451
# Method:                 Least Squares   F-statistic:                              15.39
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):                    1.90e-05
# Time:                        13:40:12   Log-Likelihood:                         -148.27
# No. Observations:                  35   AIC:                                      300.5
# Df Residuals:                      33   BIC:                                      303.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#another way to do it ask about this 
Xa=pd.DataFrame({'andrews':andrews,'neal':neal})
Xa=sm.add_constant(X)
ya=pd.DataFrame({'recov':recov})
model1a=sm.OLS(ya,Xa)
resultsa=model1a.fit()
print(resultsa.summary())
Xb=pd.DataFrame({'andrews':andrews,'neal':neal})
Xb=sm.add_constant(X)
yb=pd.DataFrame({'kpercent':kpercent})
model2=sm.OLS(yb,Xb)
resultsb=model2.fit()
print(resultsb.summary())
Xc=pd.DataFrame({'andrews':andrews,'neal':neal})
Xc=sm.add_constant(X)
yc=pd.DataFrame({'bbpercent':bbpercent})
model3=sm.OLS(yc,Xc)
resultsc=model3.fit()
print(resultsc.summary())
Xd=pd.DataFrame({'andrews':andrews,'neal':neal})
Xd=sm.add_constant(X)
yd=pd.DataFrame({'exitvelo':exitvelo})
model4=sm.OLS(yd,Xd)
resultsd=model4.fit()
print(resultsd.summary())
Xe=pd.DataFrame({'andrews':andrews,'neal':neal})
Xe=sm.add_constant(X)
ye=pd.DataFrame({'hardhit':hardhit})
model5=sm.OLS(ye,Xe)
resultse=model5.fit()
print(resultse.summary())
Xf=pd.DataFrame({'andrews':andrews,'neal':neal})
Xf=sm.add_constant(X)
yf=pd.DataFrame({'fastvelo':fastvelo})
model6=sm.OLS(yf,Xf)
resultsf=model6.fit()
print(resultsf.summary())
Xg=pd.DataFrame({'andrews':andrews,'neal':neal})
Xg=sm.add_constant(X)
yg=pd.DataFrame({'fastrpm':fastrpm})
model7=sm.OLS(yg,Xg)
resultsg=model7.fit()
print(resultsg.summary())
Xh=pd.DataFrame({'andrews':andrews,'neal':neal})
Xh=sm.add_constant(X)
yh=pd.DataFrame({'era':era})
model8=sm.OLS(yh,Xh)
resultsh=model8.fit()
print(resultsh.summary())
Xi=pd.DataFrame({'andrews':andrews,'neal':neal})
Xi=sm.add_constant(X)
yi=pd.DataFrame({'whip':whip})
model9=sm.OLS(yi,Xi)
resultsi=model9.fit()
print(resultsi.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  recov   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                  0.144
# Method:                 Least Squares   F-statistic:                     3.854
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):             0.0316
# Time:                        13:48:52   Log-Likelihood:                -127.31
# No. Observations:                  35   AIC:                             260.6
# Df Residuals:                      32   BIC:                             265.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         20.0588      2.332      8.601      0.000      15.308      24.809
# ...

# %%
#regression models with age
Xj=pd.DataFrame({'age':age})
Xj=sm.add_constant(X)
yj=pd.DataFrame({'recov':recov})
model10=sm.OLS(yj,Xj)
resultsj=model10.fit()
print(resultsj.summary())
Xk=pd.DataFrame({'age':age})
Xk=sm.add_constant(X)
yk=pd.DataFrame({'kpercent':kpercent})
model11=sm.OLS(yk,Xk)
resultsk=model11.fit()
print(resultsk.summary())
Xl=pd.DataFrame({'age':age})
Xl=sm.add_constant(X)
yl=pd.DataFrame({'bbpercent':bbpercent})
model12=sm.OLS(yl,Xl)
resultsl=model12.fit()
print(resultsl.summary())
Xm=pd.DataFrame({'age':age})
Xm=sm.add_constant(X)
ym=pd.DataFrame({'exitvelo':exitvelo})
model13=sm.OLS(ym,Xm)
resultsm=model13.fit()
print(resultsm.summary())
Xn=pd.DataFrame({'age':age})
Xn=sm.add_constant(X)
yn=pd.DataFrame({'hardhit':hardhit})
model14=sm.OLS(yn,Xn)
resultsn=model14.fit()
print(resultsn.summary())
Xo=pd.DataFrame({'age':age})
Xo=sm.add_constant(X)
yo=pd.DataFrame({'fastvelo':fastvelo})
model15=sm.OLS(yo,Xo)
resultso=model15.fit()
print(resultso.summary())
Xp=pd.DataFrame({'age':age})
Xp=sm.add_constant(X)
yp=pd.DataFrame({'fastrpm':fastrpm})
model16=sm.OLS(yp,Xp)
resultsp=model16.fit()
print(resultsp.summary())
Xq=pd.DataFrame({'age':age})
Xq=sm.add_constant(X)
yq=pd.DataFrame({'era':era})
model17=sm.OLS(yq,Xq)
resultsq=model17.fit()
print(resultsq.summary())
Xr=pd.DataFrame({'age':age})
Xr=sm.add_constant(X)
yr=pd.DataFrame({'whip':whip})
model18=sm.OLS(yr,Xr)
resultsr=model18.fit()
print(resultsr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  recov   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                  0.144
# Method:                 Least Squares   F-statistic:                     3.854
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):             0.0316
# Time:                        13:49:20   Log-Likelihood:                -127.31
# No. Observations:                  35   AIC:                             260.6
# Df Residuals:                      32   BIC:                             265.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         20.0588      2.332      8.601      0.000      15.308      24.809
# ...

# %%
pg=df.groupby('surgeon')
pg['recovery_time'].describe()
import seaborn as sns
sns.catplot(kind='box',data=df,x='surgeon',y='recovery_time')
import matplotlib.pyplot as plt 
plt.xticks(rotation=90)
# Out:
# /Users/cfox/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'Dr. James Andrews'),
#   Text(1, 0, 'Dr. George Paletta'),
#   Text(2, 0, 'Dr. Neal ElAttrache'),
#   Text(3, 0, 'Dr. Timothy Kremchek'),
#   Text(4, 0, 'Dr. Keith Meister'),
#   Text(5, 0, 'Dr. David Altchek'),
#   Text(6, 0, 'Dr. Christopher Ahmad')])

# %%
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np
from scipy.stats import ttest_ind, norm
import seaborn as sns

# %%
ttestERA = ttest_ind(era,eraNoTJ)
ttestERA
# Out:
# TtestResult(statistic=1.591418198901537, pvalue=0.11615403130184827, df=68.0)

# %%
sns.distplot(era, color='r', label = 'ERA of TJ pitchers')
sns.distplot(eraNoTJ, color='b', label = 'ERA of non TJ pitchers')
plt.xlabel('ERA difference')
plt.ylabel('probability density')
plt.title('ERA difference PDF')
plt.legend()
plt.show
# Out:
# /var/folders/kr/z0xnxn056yl5f5h8lnr83lww0000gn/T/ipykernel_45003/4144381665.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(era, color='r', label = 'ERA of TJ pitchers')
# /var/folders/kr/z0xnxn056yl5f5h8lnr83lww0000gn/T/ipykernel_45003/4144381665.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
ttestWHIP = ttest_ind(whip,whipNoTJ)
ttestWHIP
# Out:
# TtestResult(statistic=1.6424610891642755, pvalue=0.10511137950195451, df=68.0)

# %%
sns.distplot(whip, color='r', label = 'WHIP of TJ pitchers')
sns.distplot(whipNoTJ, color='b', label = 'WHIP of non TJ pitchers')
plt.xlabel('WHIP difference')
plt.ylabel('probability density')
plt.title('WHIP difference PDF')
plt.legend()
plt.show
# Out:
# /var/folders/kr/z0xnxn056yl5f5h8lnr83lww0000gn/T/ipykernel_3198/1454555306.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(whip, color='r', label = 'WHIP of TJ pitchers')
# /var/folders/kr/z0xnxn056yl5f5h8lnr83lww0000gn/T/ipykernel_3198/1454555306.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...
